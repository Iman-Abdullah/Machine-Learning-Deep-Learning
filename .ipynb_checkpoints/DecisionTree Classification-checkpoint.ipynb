# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_moons
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
# Generate synthetic classification data
X, y = make_moons(n_samples=300, noise=0.25, random_state=42)

# %%
# Split into train and test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
# Train two Decision Trees
tree_overfit = DecisionTreeClassifier(random_state=42)  # (overfitting)
tree_regularized = DecisionTreeClassifier(max_depth=3, random_state=42)  # Less flexible

tree_overfit.fit(X_train, y_train)
tree_regularized.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=3, random_state=42)

# %%
# Predict and calculate accuracy
y_pred_overfit = tree_overfit.predict(X_test)
y_pred_reg = tree_regularized.predict(X_test)

print("Overfit Tree - Train:", accuracy_score(y_train, tree_overfit.predict(X_train)))
print("Overfit Tree - Test :", accuracy_score(y_test, y_pred_overfit))
print("Regularized Tree - Train :", accuracy_score(y_train, tree_regularized.predict(X_train)))
print("Regularized Tree - Test :", accuracy_score(y_test, y_pred_reg))
# Out:
# Overfit Tree - Train: 1.0
# Overfit Tree - Test : 0.9222222222222223
# Regularized Tree - Train : 0.9
# Regularized Tree - Test : 0.9

# %%
# Plot decision boundaries
def plot_decision_boundary(clf, X, y, ax, title):
    h = 0.02
    x_min, x_max = X[:, 0].min() - .5, X[:, 0].max() + .5
    y_min, y_max = X[:, 1].min() - .5, X[:, 1].max() + .5
    xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
                         np.arange(y_min, y_max, h))
    Z = clf.predict(np.c_[xx.ravel(), yy.ravel()])
    Z = Z.reshape(xx.shape)

    ax.contourf(xx, yy, Z, alpha=0.3)
    ax.scatter(X[:, 0], X[:, 1], c=y, edgecolor='k')
    ax.set_title(title)

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 5))
plot_decision_boundary(tree_overfit, X, y, ax1, "Overfitting Tree (No max_depth)")
plot_decision_boundary(tree_regularized, X, y, ax2, "Regularized Tree (max_depth=3)")
plt.tight_layout()
plt.show()
